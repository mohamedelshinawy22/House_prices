# %% [markdown]
# # read the data

# %%
import pandas as pd
data = pd.read_csv('/content/house_prices.csv')

# %%
data.sample(10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 18872  3832500230  20150105T000000  245000.0         4       2.25
# 20412  1972202187  20141024T000000  565000.0         3       2.50
# 13872  2423069164  20150410T000000  500000.0         3       2.00
# 17066  8651402750  20150218T000000  132825.0         3       1.50
# 604    3904901710  20150224T000000  435500.0         3       2.25
# 3854   1877500090  20150211T000000  756000.0         3       2.50
# 13078  3299600040  20150214T000000  815000.0         3       2.50
# 15739   739500050  20140701T000000  260000.0         3       2.25
# 7133   3692900010  20141028T000000  445000.0         2       1.00
# 7791   1702901485  20140603T000000  440000.0         2       1.00
#
#        sqft_living  sqft_lot  floors waterfront  view  ... grade  sqft_above  \
# 18872         2140      8800     2.0          N     0  ...     7        2140
# 20412         1870      1058     3.0          N     0  ...     8        1380
# ...

# %%
data = data.drop(['id', 'date', 'zipcode'], axis = 1)

# %%
data.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.shape
# Out:
# (21613, 18)

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (21613, 18)

# %%
data.sample(3)
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 5286  241500.0         4        2.5         2500      9654     1.0          N
# 325   240500.0         2        1.0         1240     12092     1.0          N
# 8961  426000.0         4        2.5         2800      8494     2.0          N
#
#       view condition  grade  sqft_above  sqft_basement  yr_built  \
# 5286     0   Average      8        1830            670      1979
# 325      0   Average      6         960            280      1922
# 8961     0   Average      8        2800              0      2004
#
#       yr_renovated      lat     long  sqft_living15  sqft_lot15
# 5286             0  47.3137 -122.343           2500        8839
# 325           1984  47.4957 -122.352           1820        7460
# 8961             0  47.3521 -122.009           3740        8494

# %% [markdown]
# # get some insights
# 1. number of each condition in the data
# 2. avg prices
# 3. distinct values for (view, grade)

# %%
data['condition'].value_counts()
# Out:
# Average      14031
# Good          5679
# Very Good     1701
# Fair           172
# Poor            30
# Name: condition, dtype: int64

# %%
data['price'].mean()
# Out:
# 540088.1417665294

# %%
df2 = data.iloc[:,[8, 0]]

# %%
df2.head(3)
# Out:
#   condition     price
# 0   Average  221900.0
# 1   Average  538000.0
# 2   Average  180000.0

# %%
df = pd.concat([data['condition'], data['price']], axis = 1)

# %%
df.head()
# Out:
#    condition     price
# 0    Average  221900.0
# 1    Average  538000.0
# 2    Average  180000.0
# 3  Very Good  604000.0
# 4    Average  510000.0

# %%
df.groupby(['condition']).mean()
# Out:
#                    price
# condition
# Average    542012.578148
# Fair       327287.145349
# Good       521200.390033
# Poor       334431.666667
# Very Good  612418.089359

# %%
data['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %% [markdown]
# avarage of prices for each view grade

# %% [markdown]
# # data preprocessing

# %%
x = data.iloc[:, 1:]

# %%
y = data.iloc[:, 0:1]

# %%
y
# Out:
#           price
# 0      221900.0
# 1      538000.0
# 2      180000.0
# 3      604000.0
# 4      510000.0
# ...         ...
# 21608  360000.0
# 21609  400000.0
# 21610  402101.0
# 21611  400000.0
# 21612  325000.0
#
# [21613 rows x 1 columns]

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  view  \
# 0         3       1.00         1180      5650     1.0          N     0
# 1         3       2.25         2570      7242     2.0          N     0
# 2         2       1.00          770     10000     1.0          N     0
# 3         4       3.00         1960      5000     1.0          N     0
# 4         3       2.00         1680      8080     1.0          N     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0    Average      7        1180              0      1955             0
# 1    Average      7        2170            400      1951          1991
# 2    Average      6         770              0      1933             0
# 3  Very Good      7        1050            910      1965             0
# 4    Average      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257           1340        5650
# ...

# %%
x['condition'].unique()
# Out:
# array(['Average', 'Very Good', 'Good', 'Poor', 'Fair'], dtype=object)

# %%
def transform(c):
  if c == 'Poor':
    return 1
  elif c == 'Fair':
    return 2
  elif c == 'Average':
    return 3
  elif c == 'Good':
    return 4
  elif c == 'Very Good':
    return 5
  else:
    return c

# %%
x['condition'] = x['condition'].apply(transform)

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  view  \
# 0         3       1.00         1180      5650     1.0          N     0
# 1         3       2.25         2570      7242     2.0          N     0
# 2         2       1.00          770     10000     1.0          N     0
# 3         4       3.00         1960      5000     1.0          N     0
# 4         3       2.00         1680      8080     1.0          N     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257           1340        5650
# ...

# %%
x = pd.get_dummies(x)

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  condition  grade  \
# 0         3       1.00         1180      5650     1.0     0          3      7
# 1         3       2.25         2570      7242     2.0     0          3      7
# 2         2       1.00          770     10000     1.0     0          3      6
# 3         4       3.00         1960      5000     1.0     0          5      7
# 4         3       2.00         1680      8080     1.0     0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated      lat     long  \
# 0        1180              0      1955             0  47.5112 -122.257
# 1        2170            400      1951          1991  47.7210 -122.319
# 2         770              0      1933             0  47.7379 -122.233
# 3        1050            910      1965             0  47.5208 -122.393
# 4        1680              0      1987             0  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  waterfront_N  waterfront_Y
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))
x = scaler_x.fit_transform(x)
y = scaler_y.fit_transform(y)

# %%
x
# Out:
# array([[9.09090909e-02, 1.25000000e-01, 6.71698113e-02, ...,
#         5.74235339e-03, 1.00000000e+00, 0.00000000e+00],
#        [9.09090909e-02, 2.81250000e-01, 1.72075472e-01, ...,
#         8.02711852e-03, 1.00000000e+00, 0.00000000e+00],
#        [6.06060606e-02, 1.25000000e-01, 3.62264151e-02, ...,
#         8.51301880e-03, 1.00000000e+00, 0.00000000e+00],
#        ...,
#        [6.06060606e-02, 9.37500000e-02, 5.50943396e-02, ...,
#         1.55763777e-03, 1.00000000e+00, 0.00000000e+00],
#        [9.09090909e-02, 3.12500000e-01, 9.88679245e-02, ...,
#         7.30573466e-04, 1.00000000e+00, 0.00000000e+00],
#        [6.06060606e-02, 9.37500000e-02, 5.50943396e-02, ...,
#         8.10982495e-04, 1.00000000e+00, 0.00000000e+00]])

# %%
y
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %%
'''def transform(value):
  value = str(value)
  value = float(value.split()[0])
  return value'''
# Out:
# 'def transform(value):\n  value = str(value)\n  value = float(value.split()[0])\n  return value'

# %%
output = '0.06072131 USD'

# %%
print(type(output))
# Out:
# <class 'str'>

# %%
float(output.split()[0])
# Out:
# 0.06072131

# %%
output = scaler_y.inverse_transform([[float(output.split()[0])]])

# %%
output
# Out:
# array([[537999.98875]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# # welcome to AI

# %% [markdown]
# # Linear Reg

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# parameters can not be changed
# hyper parameters can be changed

# %%
model1.score(x_test, y_test) * 100
# Out:
# 70.08039781902407

# %% [markdown]
# # ploynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)
x_new = poly.fit_transform(x)

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(x_new, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()
model2.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
model2.score(x_train2, y_train2) * 100
# Out:
# 81.17727284682287

# %%
model2.score(x_test2, y_test2) * 100
# Out:
# 80.5380542476793

# %% [markdown]
# # Support vector machine

# %%
from sklearn.svm import SVR
model3 = SVR()
model3.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
model3.score(x_train, y_train)
# Out:
# 0.4484265173422959

# %%
model3.score(x_test, y_test)
# Out:
# 0.3852838397931917

# %% [markdown]
# # DT

# %%
from sklearn.tree import DecisionTreeRegressor
model4 = DecisionTreeRegressor()
model4.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model4.score(x_train, y_train)*100
# Out:
# 99.92815867464222

# %%
model4.score(x_test, y_test)*100
# Out:
# 70.28233582325957

# %% [markdown]
# # RF

# %%
from sklearn.ensemble import RandomForestRegressor
model5 = RandomForestRegressor(n_estimators= 100)
model5.fit(x_train, y_train)
# Out:
# <ipython-input-49-363147d9dfdd>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model5.fit(x_train, y_train)
# RandomForestRegressor()

# %%
model5.score(x_train, y_train)*100
# Out:
# 98.27705625261915

# %%
model5.score(x_test, y_test)*100
# Out:
# 86.79038266423527

# %% [markdown]
# # XG

# %%
from xgboost import XGBRegressor
model6 = XGBRegressor(n_estimators = 100)
model6.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model6.score(x_train, y_train)*100
# Out:
# 97.70598246943901

# %%
model6.score(x_test, y_test)*100
# Out:
# 89.9035146137443

# %%
import pickle
pickle.dump(model5, open('myweights.sav', 'wb'))

# %%
inputs = [[3, 1.00, 1180, 5650, 1.0, 0, 3, 7, 1180.0, 0.0, 1955, 0, 47.5112, -122.257, 1340.0, 5650.0, 1, 0]]

# %%
loadedModel = pickle.load(open("/content/myweights.sav",'rb'))

# %%
output = scaler_x.transform(inputs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
output = loadedModel.predict(output)

# %%
output
# Out:
# array([[229213.03]])

# %%
output = scaler_y.inverse_transform([output])

# %%
output
# Out:
# array([[229213.03]])

# %%
print(f'the price is {int(output[0][0])} USD')
# Out:
# the price is 229213 USD
